# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0b6b9a5e-0c9a-4d01-aee3-d53dc5ba5a31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b6b9a5e-0c9a-4d01-aee3-d53dc5ba5a31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv

# %%
import numpy as np

# %%
data = np.loadtxt("data.csv", delimiter=",")

# %%
data.shape
# Out:
# (100, 2)

# %%
x = data[:, 0].reshape(-1, 1)
y = data[:, 1]

# %%
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(x, y)

# %%
from sklearn.linear_model import LinearRegression
alg1 = LinearRegression()
alg1.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#gives slope
alg1.coef_
# Out:
# array([1.39566961])

# %%
#gives the intercept
alg1.intercept_
# Out:
# 4.032365053073235

# %%
import matplotlib.pyplot as plt
m = alg1.coef_[0]
c = alg1.intercept_

x_line = np.arange(30,70,0.1)
y_line = m * x_line + c
plt.plot(x_line, y_line, "r")
train_1d = X_train.reshape(75)
plt.scatter(X_train, Y_train)
plt.show()

# %%
import matplotlib.pyplot as plt
m = alg1.coef_[0]
c = alg1.intercept_

x_line = np.arange(30,70,0.1)
y_line = m * x_line + c
plt.plot(x_line, y_line, "r")
train_1d = X_test.reshape(25)
plt.scatter(X_test, Y_test)
plt.show()

# %%
#score is used to see how good the output is, if output is 1 means best
score_test=alg1.score(X_test,Y_test)
score_train=alg1.score(X_train,Y_train)
score_test,score_train
# Out:
# (0.48888070576647147, 0.6151061469510488)
